# %% [markdown]
# <a href="https://colab.research.google.com/github/aniruddha123reinforcement/DeepPath_GYM/blob/master/SQUIRE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bys0318/SQUIRE.git
# Out:
# Cloning into 'SQUIRE'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 68 (delta 25), reused 42 (delta 13), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
# %cd /content/SQUIRE
# Out:
# /content/SQUIRE

# %% [markdown]
# without rule enhancing

# %%
# %%bash
# python /content/SQUIRE/data/utils.py --dataset /content/SQUIRE/data/FB15K237 --gen-mapping --gen-eval-data --gen-train-data --num 6 --out 6_rev --max-len 3
# Out:
# -------generating mapping files-------
# -------finish mapping files-------
# -------generating evaluation files-------
# -------finish evaluation files-------
# -------generating training files-------
# -------finish training files-------
# 100%|██████████| 272115/272115 [1:01:37<00:00, 73.59it/s]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 48.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 65.5 MB/s
# ...

# %%
# %%bash
# python /content/SQUIRE/data/utils.py --dataset /content/SQUIRE/data/FB15K237 --gen-mapping --gen-eval-data
# Out:
# -------generating mapping files-------
# -------finish mapping files-------
# -------generating evaluation files-------
# -------finish evaluation files-------

# %%
# %%javascript
# java -Xmx3G -cp AnyBURL-JUNO.jar de.unima.ki.anyburl.LearnReinforced config-learn.properties

# %%
# %%bash
# python /content/SQUIRE/AnyBURL/utils.py --dataset /content/SQUIRE/data/FB15K237
# Out:
# Traceback (most recent call last):
#   File "/content/SQUIRE/AnyBURL/utils.py", line 89, in <module>
#     filter_rule(args.path, args.num, args.ratio)
#   File "/content/SQUIRE/AnyBURL/utils.py", line 34, in filter_rule
#     with open(path, 'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/SQUIRE/path1/path1000'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-21-d5269aa82f9a> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'python /content/SQUIRE/AnyBURL/utils.py --dataset /content/SQUIRE/data/FB15K237\n')
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
# ...

# %%
# %%bash
# python /content/SQUIRE/data/utils.py --dataset /content/SQUIRE/data/FB15K237  --gen-train-data --num 6 --out 6_rev_rule --max-len 3 --rule
# Out:
# -------generating training files-------
# Traceback (most recent call last):
#   File "/content/SQUIRE/data/utils.py", line 402, in <module>
#     gen_train(train_triples, relation2id, args)
#   File "/content/SQUIRE/data/utils.py", line 227, in gen_train
#     with open(os.path.join(args.dataset, 'rules.dict')) as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/SQUIRE/data/FB15K237/rules.dict'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-18-db2d7e72f3fc> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'python /content/SQUIRE/data/utils.py --dataset /content/SQUIRE/data/FB15K237  --gen-train-data --num 6 --out 6_rev_rule --max-len 3 --rule\n')
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
# ...

# %%
# %%bash
# CUDA_VISIBLE_DEVICES=1 python /content/SQUIRE/train.py --dataset /content/SQUIRE/data/FB15K237
# Out:
# usage: train.py [-h] [--embedding-dim EMBEDDING_DIM]
#                 [--hidden-size HIDDEN_SIZE] [--num-layers NUM_LAYERS]
#                 [--batch-size BATCH_SIZE] [--test-batch-size TEST_BATCH_SIZE]
#                 [--lr LR] [--dropout DROPOUT] [--weight-decay WEIGHT_DECAY]
#                 [--num-epoch NUM_EPOCH] [--save-interval SAVE_INTERVAL]
#                 [--save-dir SAVE_DIR] [--ckpt CKPT] [--dataset DATASET]
#                 [--label-smooth LABEL_SMOOTH] [--l-punish]
#                 [--beam-size BEAM_SIZE] [--no-filter-gen] [--test] [--encoder]
#                 [--trainset TRAINSET] [--loop] [--prob PROB]
#                 [--max-len MAX_LEN] [--iter]
#                 [--iter-batch-size ITER_BATCH_SIZE] [--smart-filter]
#                 [--warmup WARMUP] [--self-consistency] [--output-path]
# train.py: error: unrecognized arguments:
# ---------------------------------------------------------------------------
# ...

# %%
import transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 3.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 39.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 50.5 MB/s
# ...
